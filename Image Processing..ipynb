# %% [markdown]
# # Image Processing with Numpy and OpenCV.

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
pil = Image.open("homelander.jpeg")

# %% [markdown]
# ### Getting the Individual Pixels

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (148, 148, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=148x148>

# %%
cut = arr[:70, :70]

# %%
plt.imshow(cut)

# %%
pil = Image.open("color1.jpg")

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=728x455>

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (455, 728, 3)

# %% [markdown]
# ### Only showing the red parts

# %%
red = arr[:, :, 0]

# %%
plt.imshow(red)

# %%
pil = Image.open("homelander.jpeg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (148, 148, 3)

# %%
work = arr.copy()

# %%
work[:, :, [1, 2]].shape
# Out:
# (148, 148, 2)

# %% [markdown]
# ### Converting whole image to Red

# %%
work[:, :, [1,2]] = 0

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis=2)

# %% [markdown]
# ### Changing to GrayScale

# %%
plt.imshow(gray, cmap = "gray")

# %% [markdown]
# ### Reading image with OpenCV

# %%
import cv2

# %%
frame = cv2.imread("homelander.jpeg")

# %%
plt.imshow(frame)

# %%
rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb)

# %%
classifier = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

# %%
faces = classifier.detectMultiScale(frame)

# %%
print(faces)
# Out:
# [[50 11 54 54]]

# %%
face = faces[0]

# %%
x, y, w, h = face

# %%
face = rgb[y:y+h, x:x+w]

# %%
plt.imshow(face)

# %%
out = cv2.rectangle(rgb, (x, y), (x+w, y+h), (0, 0, 255), 4)

# %%
plt.imshow(out)
